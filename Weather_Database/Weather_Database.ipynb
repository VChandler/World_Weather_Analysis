# %%
# Import dependencies
import pandas as pd
import numpy as np
import requests
from config import weather_api_key
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(-90.000, 90.000, size=2000)
lngs = np.random.uniform(-180.000, 180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # if the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 778

# %%
# Starting URL for Weather Map API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print('Beginning Data Retrieval        ')
print('--------------------------------')

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_desc})


# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# --------------------------------
# Processing Record 1 of Set 1 | charlestown
# Processing Record 2 of Set 1 | dikson
# Processing Record 3 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | vaini
# Processing Record 6 of Set 1 | chokurdakh
# Processing Record 7 of Set 1 | taltal
# Processing Record 8 of Set 1 | mar del plata
# Processing Record 9 of Set 1 | shankargarh
# Processing Record 10 of Set 1 | castro
# Processing Record 11 of Set 1 | port lincoln
# Processing Record 12 of Set 1 | bilma
# Processing Record 13 of Set 1 | nenjiang
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | dingle
# Processing Record 16 of Set 1 | hilo
# Processing Record 17 of Set 1 | macusani
# Processing Record 18 of Set 1 | leningradskiy
# Processing Record 19 of Set 1 | muros
# Processing Record 20 of Set 1 | jamestown
# Processing Record 21 of Set 1 | carnarvon
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | ishigaki
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | nikolskoye
# Processing Record 26 of Set 1 | jalalabad
# Processing Record 27 of Set 1 | bluff
# Processing Record 28 of Set 1 | huesca
# Processing Record 29 of Set 1 | bethel
# Processing Record 30 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 1 | lorengau
# Processing Record 32 of Set 1 | hobart
# Processing Record 33 of Set 1 | lagoa
# Processing Record 34 of Set 1 | college
# Processing Record 35 of Set 1 | khatanga
# Processing Record 36 of Set 1 | constitucion
# Processing Record 37 of Set 1 | cape town
# Processing Record 38 of Set 1 | burica
# City not found. Skipping...
# Processing Record 39 of Set 1 | flin flon
# Processing Record 40 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 1 | torbay
# Processing Record 42 of Set 1 | mount barker
# Processing Record 43 of Set 1 | nanortalik
# Processing Record 44 of Set 1 | ribeira brava
# Processing Record 45 of Set 1 | nargana
# Processing Record 46 of Set 1 | butaritari
# Processing Record 47 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 1 | guerrero negro
# Processing Record 49 of Set 1 | arraial do cabo
# Processing Record 50 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 2 | kodiak
# Processing Record 2 of Set 2 | gorontalo
# Processing Record 3 of Set 2 | quelimane
# Processing Record 4 of Set 2 | punta arenas
# Processing Record 5 of Set 2 | alyangula
# Processing Record 6 of Set 2 | babusnica
# Processing Record 7 of Set 2 | qaanaaq
# Processing Record 8 of Set 2 | pisco
# Processing Record 9 of Set 2 | rawson
# Processing Record 10 of Set 2 | coolum beach
# Processing Record 11 of Set 2 | hithadhoo
# Processing Record 12 of Set 2 | sitka
# Processing Record 13 of Set 2 | egvekinot
# Processing Record 14 of Set 2 | salas
# Processing Record 15 of Set 2 | busselton
# Processing Record 16 of Set 2 | shingu
# Processing Record 17 of Set 2 | beringovskiy
# Processing Record 18 of Set 2 | bredasdorp
# Processing Record 19 of Set 2 | cahors
# Processing Record 20 of Set 2 | ellisras
# Processing Record 21 of Set 2 | cabo san lucas
# Processing Record 22 of Set 2 | adrar
# Processing Record 23 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 2 | yongan
# Processing Record 25 of Set 2 | umm kaddadah
# Processing Record 26 of Set 2 | bethal
# Processing Record 27 of Set 2 | geraldton
# Processing Record 28 of Set 2 | port alfred
# Processing Record 29 of Set 2 | iqaluit
# Processing Record 30 of Set 2 | ahuimanu
# Processing Record 31 of Set 2 | martinez
# Processing Record 32 of Set 2 | barrow
# Processing Record 33 of Set 2 | atuona
# Processing Record 34 of Set 2 | lebu
# Processing Record 35 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 36 of Set 2 | broken hill
# Processing Record 37 of Set 2 | marawi
# Processing Record 38 of Set 2 | mount gambier
# Processing Record 39 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 2 | ardakan
# Processing Record 41 of Set 2 | ilulissat
# Processing Record 42 of Set 2 | burkhala
# City not found. Skipping...
# Processing Record 43 of Set 2 | sangar
# Processing Record 44 of Set 2 | yellowknife
# Processing Record 45 of Set 2 | sturgeon falls
# Processing Record 46 of Set 2 | garda de sus
# Processing Record 47 of Set 2 | miranorte
# City not found. Skipping...
# Processing Record 48 of Set 2 | lompoc
# Processing Record 49 of Set 2 | chuy
# Processing Record 50 of Set 2 | angoche
# Processing Record 1 of Set 3 | luderitz
# Processing Record 2 of Set 3 | puerto ayora
# Processing Record 3 of Set 3 | vila velha
# Processing Record 4 of Set 3 | maldonado
# Processing Record 5 of Set 3 | berezovyy
# Processing Record 6 of Set 3 | pangnirtung
# Processing Record 7 of Set 3 | bengkulu
# Processing Record 8 of Set 3 | acapulco
# Processing Record 9 of Set 3 | yulara
# Processing Record 10 of Set 3 | longyearbyen
# Processing Record 11 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 3 | georgetown
# Processing Record 13 of Set 3 | saint-philippe
# Processing Record 14 of Set 3 | nuuk
# Processing Record 15 of Set 3 | west monroe
# Processing Record 16 of Set 3 | valparaiso
# Processing Record 17 of Set 3 | hamilton
# Processing Record 18 of Set 3 | bubaque
# Processing Record 19 of Set 3 | maridi
# Processing Record 20 of Set 3 | horadiz
# Processing Record 21 of Set 3 | batagay
# Processing Record 22 of Set 3 | clyde river
# Processing Record 23 of Set 3 | vardo
# Processing Record 24 of Set 3 | maneromango
# Processing Record 25 of Set 3 | acarau
# Processing Record 26 of Set 3 | thompson
# Processing Record 27 of Set 3 | narrabri
# Processing Record 28 of Set 3 | port macquarie
# Processing Record 29 of Set 3 | itaituba
# Processing Record 30 of Set 3 | kununurra
# Processing Record 31 of Set 3 | shieli
# Processing Record 32 of Set 3 | kasongo-lunda
# Processing Record 33 of Set 3 | sao filipe
# Processing Record 34 of Set 3 | norman wells
# Processing Record 35 of Set 3 | upernavik
# Processing Record 36 of Set 3 | severo-kurilsk
# Processing Record 37 of Set 3 | felanitx
# Processing Record 38 of Set 3 | airai
# Processing Record 39 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 3 | lagunas
# Processing Record 41 of Set 3 | kisangani
# Processing Record 42 of Set 3 | port elizabeth
# Processing Record 43 of Set 3 | kaitangata
# Processing Record 44 of Set 3 | miles city
# Processing Record 45 of Set 3 | husavik
# Processing Record 46 of Set 3 | tasiilaq
# Processing Record 47 of Set 3 | port blair
# Processing Record 48 of Set 3 | pevek
# Processing Record 49 of Set 3 | wagga wagga
# Processing Record 50 of Set 3 | quang ngai
# Processing Record 1 of Set 4 | santa lucia
# Processing Record 2 of Set 4 | berlevag
# Processing Record 3 of Set 4 | atambua
# Processing Record 4 of Set 4 | cidreira
# Processing Record 5 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 6 of Set 4 | waipawa
# Processing Record 7 of Set 4 | esperance
# Processing Record 8 of Set 4 | kapaa
# Processing Record 9 of Set 4 | nanae
# Processing Record 10 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 4 | sorland
# Processing Record 12 of Set 4 | havoysund
# Processing Record 13 of Set 4 | diplo
# Processing Record 14 of Set 4 | sambava
# Processing Record 15 of Set 4 | ratnagiri
# Processing Record 16 of Set 4 | iskateley
# Processing Record 17 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 19 of Set 4 | puerto del rosario
# Processing Record 20 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 21 of Set 4 | avarua
# Processing Record 22 of Set 4 | ambon
# Processing Record 23 of Set 4 | fukue
# Processing Record 24 of Set 4 | sola
# Processing Record 25 of Set 4 | sinnamary
# Processing Record 26 of Set 4 | gold coast
# Processing Record 27 of Set 4 | tarudant
# City not found. Skipping...
# Processing Record 28 of Set 4 | east london
# Processing Record 29 of Set 4 | bundaberg
# Processing Record 30 of Set 4 | naze
# Processing Record 31 of Set 4 | hare bay
# Processing Record 32 of Set 4 | fairbanks
# Processing Record 33 of Set 4 | saskylakh
# Processing Record 34 of Set 4 | bathsheba
# Processing Record 35 of Set 4 | beyneu
# Processing Record 36 of Set 4 | padang
# Processing Record 37 of Set 4 | chamba
# Processing Record 38 of Set 4 | tirumullaivasal
# Processing Record 39 of Set 4 | carballo
# Processing Record 40 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 4 | shahdadkot
# Processing Record 42 of Set 4 | santo tomas
# Processing Record 43 of Set 4 | bezlyudivka
# Processing Record 44 of Set 4 | harper
# Processing Record 45 of Set 4 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 46 of Set 4 | new norfolk
# Processing Record 47 of Set 4 | alihe
# Processing Record 48 of Set 4 | paita
# Processing Record 49 of Set 4 | riviere-au-renard
# Processing Record 50 of Set 4 | caxito
# Processing Record 1 of Set 5 | hervey bay
# Processing Record 2 of Set 5 | dangriga
# Processing Record 3 of Set 5 | jupiter
# Processing Record 4 of Set 5 | garden city
# Processing Record 5 of Set 5 | ribeira grande
# Processing Record 6 of Set 5 | chumikan
# Processing Record 7 of Set 5 | ca mau
# Processing Record 8 of Set 5 | neiafu
# Processing Record 9 of Set 5 | caucaia
# Processing Record 10 of Set 5 | khani
# Processing Record 11 of Set 5 | ponta do sol
# Processing Record 12 of Set 5 | codrington
# Processing Record 13 of Set 5 | cherskiy
# Processing Record 14 of Set 5 | cerkezkoy
# Processing Record 15 of Set 5 | te anau
# Processing Record 16 of Set 5 | nome
# Processing Record 17 of Set 5 | krasnoborsk
# Processing Record 18 of Set 5 | vestmannaeyjar
# Processing Record 19 of Set 5 | tukrah
# Processing Record 20 of Set 5 | celestun
# Processing Record 21 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 22 of Set 5 | talnakh
# Processing Record 23 of Set 5 | hermanus
# Processing Record 24 of Set 5 | nishihara
# Processing Record 25 of Set 5 | victoria
# Processing Record 26 of Set 5 | beira
# Processing Record 27 of Set 5 | vaitape
# Processing Record 28 of Set 5 | phangnga
# Processing Record 29 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 30 of Set 5 | san cristobal
# Processing Record 31 of Set 5 | dunedin
# Processing Record 32 of Set 5 | bindura
# Processing Record 33 of Set 5 | ilembula
# Processing Record 34 of Set 5 | tiksi
# Processing Record 35 of Set 5 | kruisfontein
# Processing Record 36 of Set 5 | mbacke
# City not found. Skipping...
# Processing Record 37 of Set 5 | jaguaquara
# Processing Record 38 of Set 5 | the valley
# Processing Record 39 of Set 5 | sinjai
# Processing Record 40 of Set 5 | sobolevo
# Processing Record 41 of Set 5 | samarai
# Processing Record 42 of Set 5 | shumskiy
# Processing Record 43 of Set 5 | jiuquan
# Processing Record 44 of Set 5 | cumaribo
# City not found. Skipping...
# Processing Record 45 of Set 5 | uren
# Processing Record 46 of Set 5 | bambous virieux
# Processing Record 47 of Set 5 | saint george
# Processing Record 48 of Set 5 | southbridge
# Processing Record 49 of Set 5 | victor harbor
# Processing Record 50 of Set 5 | walvis bay
# Processing Record 1 of Set 6 | binga
# Processing Record 2 of Set 6 | korla
# Processing Record 3 of Set 6 | faanui
# Processing Record 4 of Set 6 | trincomalee
# Processing Record 5 of Set 6 | mahebourg
# Processing Record 6 of Set 6 | chino valley
# Processing Record 7 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 8 of Set 6 | albania
# Processing Record 9 of Set 6 | saldanha
# Processing Record 10 of Set 6 | pilar
# Processing Record 11 of Set 6 | baghmara
# Processing Record 12 of Set 6 | arman
# Processing Record 13 of Set 6 | vostok
# Processing Record 14 of Set 6 | wahran
# City not found. Skipping...
# Processing Record 15 of Set 6 | sidi ali
# Processing Record 16 of Set 6 | vestmanna
# Processing Record 17 of Set 6 | filingue
# Processing Record 18 of Set 6 | manokwari
# Processing Record 19 of Set 6 | kavieng
# Processing Record 20 of Set 6 | olga
# Processing Record 21 of Set 6 | tuktoyaktuk
# Processing Record 22 of Set 6 | nelson bay
# Processing Record 23 of Set 6 | kirakira
# Processing Record 24 of Set 6 | valdivia
# Processing Record 25 of Set 6 | abiy adi
# City not found. Skipping...
# Processing Record 26 of Set 6 | porto novo
# Processing Record 27 of Set 6 | coquimbo
# Processing Record 28 of Set 6 | muzquiz
# City not found. Skipping...
# Processing Record 29 of Set 6 | lasalgaon
# Processing Record 30 of Set 6 | tyukalinsk
# Processing Record 31 of Set 6 | arlit
# Processing Record 32 of Set 6 | anloga
# Processing Record 33 of Set 6 | provideniya
# Processing Record 34 of Set 6 | lavrentiya
# Processing Record 35 of Set 6 | biak
# Processing Record 36 of Set 6 | comodoro rivadavia
# Processing Record 37 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 38 of Set 6 | mazamet
# Processing Record 39 of Set 6 | avera
# Processing Record 40 of Set 6 | tuatapere
# Processing Record 41 of Set 6 | aykhal
# Processing Record 42 of Set 6 | treinta y tres
# Processing Record 43 of Set 6 | merauke
# Processing Record 44 of Set 6 | dongying
# Processing Record 45 of Set 6 | sao raimundo nonato
# Processing Record 46 of Set 6 | kazanskaya
# Processing Record 47 of Set 6 | kahului
# Processing Record 48 of Set 6 | port augusta
# Processing Record 49 of Set 6 | hambantota
# Processing Record 50 of Set 6 | bilibino
# Processing Record 1 of Set 7 | linden
# Processing Record 2 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 7 | novoagansk
# Processing Record 4 of Set 7 | priiskovyy
# Processing Record 5 of Set 7 | grindavik
# Processing Record 6 of Set 7 | fortuna
# Processing Record 7 of Set 7 | aklera
# Processing Record 8 of Set 7 | antofagasta
# Processing Record 9 of Set 7 | pingdu
# Processing Record 10 of Set 7 | havre-saint-pierre
# Processing Record 11 of Set 7 | salinopolis
# Processing Record 12 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 13 of Set 7 | la ronge
# Processing Record 14 of Set 7 | sioux lookout
# Processing Record 15 of Set 7 | hasaki
# Processing Record 16 of Set 7 | porto torres
# Processing Record 17 of Set 7 | yacuanquer
# Processing Record 18 of Set 7 | camacha
# Processing Record 19 of Set 7 | anchorage
# Processing Record 20 of Set 7 | portland
# Processing Record 21 of Set 7 | opobo
# City not found. Skipping...
# Processing Record 22 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 23 of Set 7 | simao
# Processing Record 24 of Set 7 | mizdah
# Processing Record 25 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 7 | mendahara
# City not found. Skipping...
# Processing Record 27 of Set 7 | nanhai
# Processing Record 28 of Set 7 | ancud
# Processing Record 29 of Set 7 | haibowan
# City not found. Skipping...
# Processing Record 30 of Set 7 | nizhniy kuranakh
# Processing Record 31 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 7 | serenje
# Processing Record 33 of Set 7 | ahvaz
# Processing Record 34 of Set 7 | mulege
# Processing Record 35 of Set 7 | santiago del estero
# Processing Record 36 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 37 of Set 7 | berdigestyakh
# Processing Record 38 of Set 7 | jiamusi
# Processing Record 39 of Set 7 | margherita
# Processing Record 40 of Set 7 | pital
# Processing Record 41 of Set 7 | wolfsburg
# Processing Record 42 of Set 7 | vao
# Processing Record 43 of Set 7 | montevideo
# Processing Record 44 of Set 7 | slave lake
# Processing Record 45 of Set 7 | luba
# Processing Record 46 of Set 7 | mehamn
# Processing Record 47 of Set 7 | tura
# Processing Record 48 of Set 7 | westport
# Processing Record 49 of Set 7 | najran
# Processing Record 50 of Set 7 | yuli
# Processing Record 1 of Set 8 | kargasok
# Processing Record 2 of Set 8 | hekinan
# Processing Record 3 of Set 8 | komsomolskiy
# Processing Record 4 of Set 8 | salisbury
# Processing Record 5 of Set 8 | saryg-sep
# Processing Record 6 of Set 8 | general pico
# Processing Record 7 of Set 8 | gemena
# Processing Record 8 of Set 8 | necochea
# Processing Record 9 of Set 8 | shenjiamen
# Processing Record 10 of Set 8 | tuggurt
# City not found. Skipping...
# Processing Record 11 of Set 8 | narsaq
# Processing Record 12 of Set 8 | kamaishi
# Processing Record 13 of Set 8 | kyren
# Processing Record 14 of Set 8 | paamiut
# Processing Record 15 of Set 8 | aripuana
# Processing Record 16 of Set 8 | port hardy
# Processing Record 17 of Set 8 | bibai
# Processing Record 18 of Set 8 | cockburn town
# Processing Record 19 of Set 8 | dubbo
# Processing Record 20 of Set 8 | malpe
# Processing Record 21 of Set 8 | george town
# Processing Record 22 of Set 8 | riyadh
# Processing Record 23 of Set 8 | sisimiut
# Processing Record 24 of Set 8 | mbandaka
# Processing Record 25 of Set 8 | baruun-urt
# Processing Record 26 of Set 8 | cuiluan
# Processing Record 27 of Set 8 | lasa
# Processing Record 28 of Set 8 | swift current
# Processing Record 29 of Set 8 | kiunga
# Processing Record 30 of Set 8 | phan thiet
# Processing Record 31 of Set 8 | igrim
# Processing Record 32 of Set 8 | takanosu
# Processing Record 33 of Set 8 | kilindoni
# Processing Record 34 of Set 8 | sur
# Processing Record 35 of Set 8 | okhotsk
# Processing Record 36 of Set 8 | lake charles
# Processing Record 37 of Set 8 | aginskoye
# Processing Record 38 of Set 8 | andevoranto
# City not found. Skipping...
# Processing Record 39 of Set 8 | karratha
# Processing Record 40 of Set 8 | ivolginsk
# Processing Record 41 of Set 8 | bury
# Processing Record 42 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 43 of Set 8 | billings
# Processing Record 44 of Set 8 | cachoeira do sul
# Processing Record 45 of Set 8 | kaeo
# Processing Record 46 of Set 8 | mikumi
# Processing Record 47 of Set 8 | lodja
# Processing Record 48 of Set 8 | tobermory
# Processing Record 49 of Set 8 | gumla
# Processing Record 50 of Set 8 | isangel
# Processing Record 1 of Set 9 | haines junction
# Processing Record 2 of Set 9 | baie-saint-paul
# Processing Record 3 of Set 9 | zeya
# Processing Record 4 of Set 9 | sharjah
# Processing Record 5 of Set 9 | woodburn
# Processing Record 6 of Set 9 | belluno
# Processing Record 7 of Set 9 | capao bonito
# Processing Record 8 of Set 9 | souillac
# Processing Record 9 of Set 9 | meulaboh
# Processing Record 10 of Set 9 | ahipara
# Processing Record 11 of Set 9 | torres
# Processing Record 12 of Set 9 | inhambane
# Processing Record 13 of Set 9 | abbeville
# Processing Record 14 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 15 of Set 9 | asau
# Processing Record 16 of Set 9 | les cayes
# Processing Record 17 of Set 9 | mayo
# Processing Record 18 of Set 9 | luanda
# Processing Record 19 of Set 9 | stokmarknes
# Processing Record 20 of Set 9 | ust-nera
# Processing Record 21 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 22 of Set 9 | pacific grove
# Processing Record 23 of Set 9 | kawambwa
# Processing Record 24 of Set 9 | athens
# Processing Record 25 of Set 9 | halifax
# Processing Record 26 of Set 9 | margate
# Processing Record 27 of Set 9 | sao joao da barra
# Processing Record 28 of Set 9 | makambako
# Processing Record 29 of Set 9 | juxian
# City not found. Skipping...
# Processing Record 30 of Set 9 | nadym
# Processing Record 31 of Set 9 | daru
# Processing Record 32 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 33 of Set 9 | kasongo
# Processing Record 34 of Set 9 | khilok
# Processing Record 35 of Set 9 | alekseyevsk
# Processing Record 36 of Set 9 | kropotkin
# Processing Record 37 of Set 9 | kalmunai
# Processing Record 38 of Set 9 | ostersund
# Processing Record 39 of Set 9 | virginia beach
# Processing Record 40 of Set 9 | vila franca do campo
# Processing Record 41 of Set 9 | ketchikan
# Processing Record 42 of Set 9 | mudanjiang
# Processing Record 43 of Set 9 | namatanai
# Processing Record 44 of Set 9 | kupang
# Processing Record 45 of Set 9 | turayf
# Processing Record 46 of Set 9 | novosergiyevka
# Processing Record 47 of Set 9 | jomalig
# City not found. Skipping...
# Processing Record 48 of Set 9 | gimli
# Processing Record 49 of Set 9 | alexandria
# Processing Record 50 of Set 9 | clacton-on-sea
# Processing Record 1 of Set 10 | ust-tsilma
# Processing Record 2 of Set 10 | kothen
# Processing Record 3 of Set 10 | basco
# Processing Record 4 of Set 10 | buraydah
# Processing Record 5 of Set 10 | henties bay
# Processing Record 6 of Set 10 | yomou
# Processing Record 7 of Set 10 | puke
# Processing Record 8 of Set 10 | hailey
# Processing Record 9 of Set 10 | svetlogorsk
# Processing Record 10 of Set 10 | sitio novo do tocantins
# Processing Record 11 of Set 10 | cukai
# Processing Record 12 of Set 10 | waddan
# Processing Record 13 of Set 10 | soe
# Processing Record 14 of Set 10 | ixtapa
# Processing Record 15 of Set 10 | coahuayana
# Processing Record 16 of Set 10 | obo
# Processing Record 17 of Set 10 | labuhan
# Processing Record 18 of Set 10 | namibe
# Processing Record 19 of Set 10 | waitati
# Processing Record 20 of Set 10 | whitehorse
# Processing Record 21 of Set 10 | sept-iles
# Processing Record 22 of Set 10 | barmer
# Processing Record 23 of Set 10 | roma
# Processing Record 24 of Set 10 | madingou
# Processing Record 25 of Set 10 | tremedal
# Processing Record 26 of Set 10 | morant bay
# Processing Record 27 of Set 10 | umm lajj
# Processing Record 28 of Set 10 | ijaki
# City not found. Skipping...
# Processing Record 29 of Set 10 | tabas
# Processing Record 30 of Set 10 | santiago
# Processing Record 31 of Set 10 | erzin
# Processing Record 32 of Set 10 | las margaritas
# Processing Record 33 of Set 10 | kodinsk
# Processing Record 34 of Set 10 | tchibanga
# Processing Record 35 of Set 10 | cayenne
# Processing Record 36 of Set 10 | gornopravdinsk
# Processing Record 37 of Set 10 | palaiokhora
# City not found. Skipping...
# Processing Record 38 of Set 10 | menongue
# Processing Record 39 of Set 10 | vila
# Processing Record 40 of Set 10 | sawakin
# Processing Record 41 of Set 10 | orchard homes
# Processing Record 42 of Set 10 | jaciara
# Processing Record 43 of Set 10 | le port
# Processing Record 44 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 45 of Set 10 | inderborskiy
# City not found. Skipping...
# Processing Record 46 of Set 10 | jieshi
# Processing Record 47 of Set 10 | luena
# Processing Record 48 of Set 10 | niamey
# Processing Record 49 of Set 10 | okha
# Processing Record 50 of Set 10 | anyama
# Processing Record 1 of Set 11 | itacoatiara
# Processing Record 2 of Set 11 | anito
# Processing Record 3 of Set 11 | zhigansk
# Processing Record 4 of Set 11 | pringsewu
# Processing Record 5 of Set 11 | ornskoldsvik
# Processing Record 6 of Set 11 | tahta
# Processing Record 7 of Set 11 | laguna
# Processing Record 8 of Set 11 | one hundred mile house
# City not found. Skipping...
# Processing Record 9 of Set 11 | capitao poco
# Processing Record 10 of Set 11 | gberia fotombu
# Processing Record 11 of Set 11 | umm durman
# City not found. Skipping...
# Processing Record 12 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 13 of Set 11 | geelong
# Processing Record 14 of Set 11 | tshikapa
# Processing Record 15 of Set 11 | tapiramuta
# Processing Record 16 of Set 11 | chaman
# Processing Record 17 of Set 11 | woodward
# Processing Record 18 of Set 11 | sosnovo-ozerskoye
# Processing Record 19 of Set 11 | robertsport
# Processing Record 20 of Set 11 | nehe
# Processing Record 21 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 11 | nantucket
# Processing Record 23 of Set 11 | jutai
# Processing Record 24 of Set 11 | huarmey
# Processing Record 25 of Set 11 | santa marta
# Processing Record 26 of Set 11 | tekkali
# Processing Record 27 of Set 11 | oyama
# Processing Record 28 of Set 11 | san patricio
# Processing Record 29 of Set 11 | ormara
# Processing Record 30 of Set 11 | morondava
# Processing Record 31 of Set 11 | hofn
# Processing Record 32 of Set 11 | maragogi
# Processing Record 33 of Set 11 | peniche
# Processing Record 34 of Set 11 | mangai
# Processing Record 35 of Set 11 | sale
# Processing Record 36 of Set 11 | rio gallegos
# Processing Record 37 of Set 11 | kieta
# Processing Record 38 of Set 11 | calvinia
# Processing Record 39 of Set 11 | flinders
# Processing Record 40 of Set 11 | carutapera
# Processing Record 41 of Set 11 | manta
# Processing Record 42 of Set 11 | stoyba
# City not found. Skipping...
# Processing Record 43 of Set 11 | lugazi
# Processing Record 44 of Set 11 | edd
# Processing Record 45 of Set 11 | olafsvik
# Processing Record 46 of Set 11 | touros
# Processing Record 47 of Set 11 | derzhavinsk
# Processing Record 48 of Set 11 | karamea
# City not found. Skipping...
# Processing Record 49 of Set 11 | rock sound
# Processing Record 50 of Set 11 | raudeberg
# Processing Record 1 of Set 12 | tigil
# Processing Record 2 of Set 12 | am timan
# Processing Record 3 of Set 12 | columbia
# Processing Record 4 of Set 12 | bell ville
# Processing Record 5 of Set 12 | arteaga
# Processing Record 6 of Set 12 | la brea
# Processing Record 7 of Set 12 | uhlove
# Processing Record 8 of Set 12 | moron
# Processing Record 9 of Set 12 | kambove
# Processing Record 10 of Set 12 | tawnat
# City not found. Skipping...
# Processing Record 11 of Set 12 | aksakovo
# Processing Record 12 of Set 12 | la grande
# Processing Record 13 of Set 12 | saint-augustin
# Processing Record 14 of Set 12 | sakakah
# Processing Record 15 of Set 12 | lima
# Processing Record 16 of Set 12 | ekibastuz
# Processing Record 17 of Set 12 | gat
# Processing Record 18 of Set 12 | balkanabat
# Processing Record 19 of Set 12 | rapallo
# Processing Record 20 of Set 12 | russell
# Processing Record 21 of Set 12 | senneterre
# Processing Record 22 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 23 of Set 12 | kashima
# Processing Record 24 of Set 12 | oussouye
# Processing Record 25 of Set 12 | baghdad
# Processing Record 26 of Set 12 | yazoo city
# Processing Record 27 of Set 12 | aswan
# Processing Record 28 of Set 12 | rach gia
# Processing Record 29 of Set 12 | griffith
# Processing Record 30 of Set 12 | riohacha
# Processing Record 31 of Set 12 | poum
# Processing Record 32 of Set 12 | talara
# Processing Record 33 of Set 12 | ballina
# Processing Record 34 of Set 12 | harrismith
# Processing Record 35 of Set 12 | kamenka
# Processing Record 36 of Set 12 | morro bay
# Processing Record 37 of Set 12 | chifeng
# Processing Record 38 of Set 12 | makung
# City not found. Skipping...
# Processing Record 39 of Set 12 | sayabec
# City not found. Skipping...
# Processing Record 40 of Set 12 | north bend
# Processing Record 41 of Set 12 | paradwip
# City not found. Skipping...
# Processing Record 42 of Set 12 | tommot
# Processing Record 43 of Set 12 | olinda
# Processing Record 44 of Set 12 | san fernando
# Processing Record 45 of Set 12 | darhan
# Processing Record 46 of Set 12 | pozo colorado
# Processing Record 47 of Set 12 | srednekolymsk
# Processing Record 48 of Set 12 | san francisco del mar
# Processing Record 49 of Set 12 | nizhniy tsasuchey
# Processing Record 50 of Set 12 | asifabad
# Processing Record 1 of Set 13 | werda
# Processing Record 2 of Set 13 | muroto
# Processing Record 3 of Set 13 | grafton
# Processing Record 4 of Set 13 | tubuala
# Processing Record 5 of Set 13 | ornes
# Processing Record 6 of Set 13 | juneau
# Processing Record 7 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 8 of Set 13 | lingyuan
# Processing Record 9 of Set 13 | aviles
# Processing Record 10 of Set 13 | ginir
# Processing Record 11 of Set 13 | lokosovo
# Processing Record 12 of Set 13 | aldan
# Processing Record 13 of Set 13 | mitsamiouli
# Processing Record 14 of Set 13 | bridlington
# Processing Record 15 of Set 13 | half moon bay
# Processing Record 16 of Set 13 | villa carlos paz
# Processing Record 17 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 18 of Set 13 | batavia
# Processing Record 19 of Set 13 | teneguiban
# City not found. Skipping...
# Processing Record 20 of Set 13 | porto santo
# Processing Record 21 of Set 13 | friesach
# Processing Record 22 of Set 13 | port hedland
# Processing Record 23 of Set 13 | marystown
# Processing Record 24 of Set 13 | safwah
# City not found. Skipping...
# Processing Record 25 of Set 13 | bud
# Processing Record 26 of Set 13 | sayat
# Processing Record 27 of Set 13 | quatre cocos
# Processing Record 28 of Set 13 | iquique
# Processing Record 29 of Set 13 | yuanping
# Processing Record 30 of Set 13 | ulaangom
# Processing Record 31 of Set 13 | moree
# Processing Record 32 of Set 13 | luau
# Processing Record 33 of Set 13 | san pedro
# Processing Record 34 of Set 13 | makhachkala
# Processing Record 35 of Set 13 | faya
# Processing Record 36 of Set 13 | nabire
# Processing Record 37 of Set 13 | oxbow
# Processing Record 38 of Set 13 | sfantu gheorghe
# Processing Record 39 of Set 13 | lata
# Processing Record 40 of Set 13 | maumere
# Processing Record 41 of Set 13 | kosikha
# Processing Record 42 of Set 13 | tautira
# Processing Record 43 of Set 13 | fare
# Processing Record 44 of Set 13 | humaita
# Processing Record 45 of Set 13 | dolinsk
# Processing Record 46 of Set 13 | ostrovnoy
# Processing Record 47 of Set 13 | chase
# Processing Record 48 of Set 13 | sulphur
# Processing Record 49 of Set 13 | kalachinsk
# Processing Record 50 of Set 13 | japura
# Processing Record 1 of Set 14 | minnedosa
# Processing Record 2 of Set 14 | kungurtug
# Processing Record 3 of Set 14 | christchurch
# Processing Record 4 of Set 14 | niihama
# Processing Record 5 of Set 14 | limulunga
# Processing Record 6 of Set 14 | sabang
# Processing Record 7 of Set 14 | winslow
# Processing Record 8 of Set 14 | aksarka
# Processing Record 9 of Set 14 | katsuura
# Processing Record 10 of Set 14 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 11 of Set 14 | kulhudhuffushi
# Processing Record 12 of Set 14 | roald
# Processing Record 13 of Set 14 | kurilsk
# Processing Record 14 of Set 14 | panjakent
# Processing Record 15 of Set 14 | kananga
# Processing Record 16 of Set 14 | klaksvik
# Processing Record 17 of Set 14 | lodwar
# Processing Record 18 of Set 14 | zheleznodorozhnyy
# Processing Record 19 of Set 14 | mweka
# Processing Record 20 of Set 14 | hun
# Processing Record 21 of Set 14 | mbigou
# Processing Record 22 of Set 14 | mao
# Processing Record 23 of Set 14 | santa maria
# Processing Record 24 of Set 14 | morrope
# Processing Record 25 of Set 14 | fort nelson
# Processing Record 26 of Set 14 | dzhusaly
# City not found. Skipping...
# Processing Record 27 of Set 14 | moutier
# Processing Record 28 of Set 14 | cilegon
# Processing Record 29 of Set 14 | salalah
# Processing Record 30 of Set 14 | turukhansk
# Processing Record 31 of Set 14 | kuytun
# Processing Record 32 of Set 14 | akdepe
# Processing Record 33 of Set 14 | sao jose da coroa grande
# Processing Record 34 of Set 14 | alofi
# Processing Record 35 of Set 14 | aksu
# Processing Record 36 of Set 14 | kysyl-syr
# Processing Record 37 of Set 14 | nouadhibou
# Processing Record 38 of Set 14 | maceio
# Processing Record 39 of Set 14 | cananea
# Processing Record 40 of Set 14 | snasa
# Processing Record 41 of Set 14 | dharchula
# Processing Record 42 of Set 14 | bandar-e lengeh
# Processing Record 43 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 44 of Set 14 | agadez
# Processing Record 45 of Set 14 | cervo
# Processing Record 46 of Set 14 | ndele
# Processing Record 47 of Set 14 | hay river
# Processing Record 48 of Set 14 | dhidhdhoo
# Processing Record 49 of Set 14 | arona
# Processing Record 50 of Set 14 | kerema
# Processing Record 1 of Set 15 | terney
# Processing Record 2 of Set 15 | pemba
# Processing Record 3 of Set 15 | wewak
# Processing Record 4 of Set 15 | krasnoselkup
# Processing Record 5 of Set 15 | kidal
# Processing Record 6 of Set 15 | rexburg
# Processing Record 7 of Set 15 | siguiri
# Processing Record 8 of Set 15 | pingliang
# Processing Record 9 of Set 15 | conde
# Processing Record 10 of Set 15 | hovd
# Processing Record 11 of Set 15 | qingdao
# Processing Record 12 of Set 15 | almaznyy
# Processing Record 13 of Set 15 | north augusta
# Processing Record 14 of Set 15 | san policarpo
# Processing Record 15 of Set 15 | bad liebenzell
# Processing Record 16 of Set 15 | belaya gora
# Processing Record 17 of Set 15 | soyo
# Processing Record 18 of Set 15 | pantelho
# Processing Record 19 of Set 15 | crossville
# Processing Record 20 of Set 15 | neuquen
# Processing Record 21 of Set 15 | general roca
# Processing Record 22 of Set 15 | yeppoon
# Processing Record 23 of Set 15 | barra do garcas
# Processing Record 24 of Set 15 | rio grande
# Processing Record 25 of Set 15 | asfi
# Processing Record 26 of Set 15 | roswell
# Processing Record 27 of Set 15 | hukuntsi
# Processing Record 28 of Set 15 | canavieiras
# Processing Record 29 of Set 15 | kaseda
# Processing Record 30 of Set 15 | winton
# Processing Record 31 of Set 15 | naliya
# Processing Record 32 of Set 15 | bichura
# Processing Record 33 of Set 15 | ialibu
# Processing Record 34 of Set 15 | revelstoke
# Processing Record 35 of Set 15 | hai phong
# City not found. Skipping...
# Processing Record 36 of Set 15 | auki
# Processing Record 37 of Set 15 | port-gentil
# Processing Record 38 of Set 15 | praia
# Processing Record 39 of Set 15 | lamu
# Processing Record 40 of Set 15 | xuddur
# Processing Record 41 of Set 15 | altay
# Processing Record 42 of Set 15 | san jeronimo
# Processing Record 43 of Set 15 | guaymas
# Processing Record 44 of Set 15 | baykit
# Processing Record 45 of Set 15 | eyl
# Processing Record 46 of Set 15 | shawville
# Processing Record 47 of Set 15 | store heddinge
# Processing Record 48 of Set 15 | tsabong
# Processing Record 49 of Set 15 | nanaimo
# Processing Record 50 of Set 15 | hatillo
# Processing Record 1 of Set 16 | braganca
# Processing Record 2 of Set 16 | palmer
# Processing Record 3 of Set 16 | karaul
# City not found. Skipping...
# Processing Record 4 of Set 16 | hit
# Processing Record 5 of Set 16 | kautokeino
# Processing Record 6 of Set 16 | zavyalovo
# Processing Record 7 of Set 16 | ciocanesti
# Processing Record 8 of Set 16 | louisbourg
# City not found. Skipping...
# Processing Record 9 of Set 16 | kashi
# Processing Record 10 of Set 16 | yirol
# City not found. Skipping...
# Processing Record 11 of Set 16 | mgachi
# Processing Record 12 of Set 16 | rundu
# Processing Record 13 of Set 16 | werder
# Processing Record 14 of Set 16 | koumac
# Processing Record 15 of Set 16 | cobourg
# Processing Record 16 of Set 16 | benguela
# Processing Record 17 of Set 16 | bogo
# Processing Record 18 of Set 16 | agirish
# Processing Record 19 of Set 16 | mirnyy
# Processing Record 20 of Set 16 | maniitsoq
# Processing Record 21 of Set 16 | seoul
# Processing Record 22 of Set 16 | chara
# Processing Record 23 of Set 16 | bhopal
# Processing Record 24 of Set 16 | praia da vitoria
# Processing Record 25 of Set 16 | road town
# Processing Record 26 of Set 16 | maryville
# Processing Record 27 of Set 16 | sirohi
# Processing Record 28 of Set 16 | moindou
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert to dataframe
city_weather_df = pd.DataFrame(city_data)
city_weather_df.head()
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Charlestown      AU -32.9500  151.6667     77.22        36           0
# 1       Dikson      RU  73.5069   80.5464     34.39        74          12
# 2      Ushuaia      AR -54.8000  -68.3000     38.86        70           0
# 3        Vaini      TO -21.2000 -175.2000     71.76        94          75
# 4   Chokurdakh      RU  70.6333  147.9167     36.07        52          79
#
#    Wind Speed Current Description
# 0        3.00           clear sky
# 1       25.37          few clouds
# 2        0.00           clear sky
# 3       14.97          light rain
# 4        8.01       broken clouds

# %%
# Create the output file (CSV)
output_data_file = "WeatherPy_Database.csv"
# Export the City_data into a csv.
city_weather_df.to_csv(output_data_file, index_label="City_ID")
